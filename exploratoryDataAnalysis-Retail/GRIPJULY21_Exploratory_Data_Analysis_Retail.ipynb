# %% [markdown]
# <a href="https://colab.research.google.com/github/sudama-Inc/GRIP-TheSparkFoundation-Internship/blob/main/GRIPJULY21_Exploratory_Data_Analysis_Retail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sudama Sharma
# ##### DATA SCIENCE AND BUSINESS ANALYTICS INTERN @ THE SPARKS FOUNDATION
# ##### #GRIPJULY21 #TSF #DATASCIENCE
# ##### DATASET : SAMPLESUPERSTORE.CSV (https://bit.ly/3i4rbWl)

# %% [markdown]
# # Task 2: Exploratory Data Analysis - Retail
# ##### Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’ As a business manager, try to find out the weak areas where you can work to make more profit.
# ##### What all business problems you can derive by exploring the data?

# %%
# import all required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Mount the google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import & Read the dataset from Google Drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
df.info()   # Information about the data and colums
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# #### No missing values in the dataset.

# %% [markdown]
# ##### checking for the unique values across each column in dataset

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### Comparing Profit and Sales

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['Sales'],color='red',label='Sales',shade=True,bw=25)
sns.kdeplot(df['Profit'],color='Blue',label='Profit',shade=True,bw=25)
plt.xlim([-50000,80000])
plt.legend()

# %% [markdown]
# ##### Profit is more than that of sale but there are some areas where profit could be increased.

# %% [markdown]
# ## Univariate Analysis

# %%
# plot the graph for Sales variable
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.title('Sales_Distribution',fontsize=20)
sns.distplot(df['Sales'],color='red')

plt.subplot(1,2,2)
sns.boxplot(df['Sales'])
plt.title('Sales_Boxplot',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sales_Boxplot')

# %% [markdown]
# #### There are some outliers in the sales

# %%
# plot the graph for Profit variable
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.title('Profit_Distribution',fontsize=20)
sns.distplot(df['Profit'],color='green')

plt.subplot(1,2,2)
sns.boxplot(df['Profit'])
plt.title('Profit_Boxplot',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Profit_Boxplot')

# %%
# plot the graph for Profit variable
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.title('Quantity_Distribution',fontsize=20)
sns.distplot(df['Quantity'])

plt.subplot(1,2,2)
sns.boxplot(df['Quantity'])
plt.title('Quantity_Boxplot',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Quantity_Boxplot')

# %% [markdown]
# #### Quantity distribution is right skewed having some outliers.

# %%
# plot the graph for Profit variable
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.title('Discount_Distribution',fontsize=20)
sns.distplot(df['Discount'],color='orange')

plt.subplot(1,2,2)
sns.boxplot(df['Discount'])
plt.title('Discount_Boxplot',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Discount_Boxplot')

# %% [markdown]
# #### Maximum discount is between 0-20%

# %%
# Count plot of each column

fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(10,7));

sns.countplot(df['Category'],ax=axs[0][0])
sns.countplot(df['Segment'],ax=axs[0][1])
sns.countplot(df['Ship Mode'],ax=axs[1][0])
sns.countplot(df['Region'],ax=axs[1][1])
axs[0][0].set_title('Category',fontsize=20)
axs[0][1].set_title('Segment',fontsize=20)
axs[1][0].set_title('Ship Mode',fontsize=20)
axs[1][1].set_title('Region',fontsize=20)


plt.tight_layout()

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Sub-Category'])
plt.title('Sub-Category',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sub-Category')

# %%
plt.figure(figsize=(18,5))
sns.countplot(df['State'])
plt.xticks(rotation=90)
plt.title('State',fontsize=20)
# Out:
# Text(0.5, 1.0, 'State')

# %% [markdown]
# #### California state is having highest number of orders and below that New York city having second highest number of orders.

# %%
plt.figure(figsize=(18,5))
sns.countplot(df['Quantity'])
plt.title('Quantity',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Quantity')

# %% [markdown]
# #### Quantity 2 and 3 are most comman to be sold.

# %%
plt.figure(figsize=(18,5))
sns.countplot(df['Discount'])
plt.xticks(rotation=90)
plt.title('Discount',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Discount')

# %% [markdown]
# #### 0 Discount orders are most comman means that, Sale without discount is large than with discount

# %% [markdown]
# # Analysis using Pairplot of each column

# %%
sns.pairplot(df)

# %% [markdown]
# # [1] Based on the Catagory

# %%
sns.pairplot(df,hue='Category')

# %% [markdown]
# ##### 1. Technology Category is the dominent over all other categories.If go through discount vs profit we realize that even after
# ##### 2. Giving 50% discount there was the loss and without discount there was a better sale than with discount

# %% [markdown]
# # [2] Based on Region

# %%
sns.pairplot(df,hue='Region')

# %% [markdown]
# ##### Most of sales is in the East region and also the profit goes somehow increasing in the east area as the sales increases.

# %% [markdown]
# # [3] Based on the segment

# %%
sns.pairplot(df,hue='Segment')

# %% [markdown]
# # Heatmap for Correlation

# %%
sns.heatmap(df.corr(),cmap='rocket_r',annot=True)

# %% [markdown]
# ### From above Heatmap:
# ##### 1.   Sales and Profit are Moderately Correlated.
# ##### 2.   Discount and Profit are Negatively Correlated
# ##### 3.   Quantity and Profit are less Moderately Correlated.

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Sales',y='Profit',data=df)

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Ship Mode',y='Profit',data=df)

# %% [markdown]
# ##### Average Profit is higher for the Shipping mode First Class than others

# %% [markdown]
# # Statewise Deal Analysis

# %%
df['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
df1 = df['State'].value_counts()
df1.head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
df1.plot(kind='bar',figsize=(15,5),color='red')
plt.ylabel('Frequency / Number of deals')
plt.xlabel('States')

plt.title('State Wise Dealings', fontsize = 20)
plt.show()

# %% [markdown]
# ##### Here is top 3 state where deals are Highest.
# 1.   Califonia
# 2.   New York
# 3.   Texas
#
# ##### Wyoming: Lowest Number of deal

# %%
df['State'].value_counts().mean()
# Out:
# 203.9591836734694

# %% [markdown]
# ##### 1. Average number of deal per state is 204.
# ##### 2. City Wise analysis of the dealing

# %%
df2 = df['City'].value_counts()
df2=df2.head(50)

# %%
df2.plot(kind='bar',figsize=(15,5))
plt.ylabel('Frequency / Number of deals')
plt.xlabel('City')

plt.title('City Wise Dealings', fontsize = 20)
plt.show()

# %% [markdown]
# #### Here is top 3 city where deals are Highest.
# 1.   New York City
# 2.   Los Angeles
# 3.   Philadelphia

# %%
df['City'].value_counts().mean()
# Out:
# 18.821092278719398

# %% [markdown]
# #### Average number of deal per city is 19.
# #### Segment wise analysis of Profit, Discount and

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df_segment= df.groupby(['Segment'])[['Sales', 'Discount', 'Profit']].mean()
df_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %% [markdown]
# #1. sales 2. Discount 3. Profit

# %%
df_segment.plot.pie(subplots=True, 
                    autopct='%1.1f%%',
                    figsize=(12, 20),
                    startangle=90,     # start angle 90° (Africa)
                    shadow=True,
                    labels = df_segment.index)
plt.title('Segment wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'Segment wise analysis of Sale, Discount, profit')

# %% [markdown]
# ## Sales:
# 1.   Consumer : 32%
# 2.   Corporate - 33.5%
# 3.   Home Office : 34.5%
#
# ## Discount :
# 1.   Consumer :  15.8%
# 2.   Corporate -  15.8%
# 3.   Home Office : 14.7%
#
# ## Profit :
# 1.   Consumer :  15.8%
# 2.   Corporate -  15.8%
# 3.   Home Office : 14.7%

# %% [markdown]
# # Statewise analysis of Profit Discount and sell

# %%
df['State'].value_counts().head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
df_state= df.groupby(['State'])[['Sales', 'Discount', 'Profit']].mean()
df_state.head(10)
# Out:
#                            Sales  Discount      Profit
# State
# Alabama               319.846557  0.000000   94.865989
# Arizona               157.508933  0.303571  -15.303235
# Arkansas              194.635500  0.000000   66.811452
# California            228.729451  0.072764   38.171608
# Colorado              176.418231  0.316484  -35.867351
# Connecticut           163.223866  0.007317   42.823071
# Delaware              285.948635  0.006250  103.930988
# District of Columbia  286.502000  0.000000  105.958930
# Florida               233.612815  0.299347   -8.875461
# Georgia               266.825217  0.000000   88.315453

# %% [markdown]
# # [1] Statewise Profit Analysis

# %%
df_state1=df_state.sort_values('Profit')

df_state1[['Profit']].plot(kind = 'bar', figsize = (15,4),color='green')
plt.title('State wise Profit Analysis', fontsize = 20)
plt.ylabel('Profit per Sate')
plt.xlabel('States')
plt.show()

# %% [markdown]
# ## RESULT:
#
# 1.   Vermont: Highest Profit
# 2.   Ohio: Lowest Profit

# %% [markdown]
# # [2] Statewise Sale Analysis

# %%
df_state['Sales'].plot(kind='pie',
                        figsize = (20,20),
                        autopct='%1.1f%%',
                        startangle=90,     # start angle 90° (Africa)
                        shadow=True)
plt.title('State wise analysis of Sale',fontsize=15)
# Out:
# Text(0.5, 1.0, 'State wise analysis of Sale')

# %% [markdown]
# 1.   Highest amount of sales= Wyoming(11.8%)
# 2.   Lowest amount of sales= South Dakota(0.8%)

# %% [markdown]
# # [3] Statewise Discount Analysis

# %%
df_state1['Discount'].plot(kind='bar',figsize=(18,5))
plt.title('State wise analysis of Discount', fontsize=20)
# Out:
# Text(0.5, 1.0, 'State wise analysis of Discount')

# %% [markdown]
# #### RESULT: Illinois at the top

# %% [markdown]
# # Citywise Analysis of the Profit

# %%
df_city= df.groupby(['City'])[['Sales', 'Discount', 'Profit']].mean()
df_city = df_city.sort_values('Profit')
df_city.head()
# Out:
#                  Sales  Discount      Profit
# City
# Bethlehem   337.926800  0.380000 -200.619160
# Champaign   151.960000  0.600000 -182.352000
# Oswego      107.326000  0.600000 -178.709200
# Round Rock  693.436114  0.274286 -169.061614
# Lancaster   215.031826  0.315217 -157.371052

# %% [markdown]
# #1.Low Profit

# %%
df_city['Profit'].head(30).plot(kind='bar',figsize=(15,5),color = 'red')
plt.title('City wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of Sale, Discount, profit')

# %% [markdown]
# # 2. High Profit

# %%
df_city['Profit'].tail(30).plot(kind='bar',figsize=(15,5),color = 'red')
plt.title('City wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of Sale, Discount, profit')

# %% [markdown]
# 1.   30 CITIES WHICH HAS PROFIT IN POSITIVE
# 2.   30 CITIES WHICH HAS PROFIT IN NEGATIVE
# 3.   THE BALANCE IS PRETTY GOOD HERE!

# %% [markdown]
# ### QUANTITY WISE SALES, PROFIT AND DISCOUNT ANALYSIS

# %%
df_quantity = df.groupby(['Quantity'])[['Sales', 'Discount', 'Profit']].mean()
df_quantity.head(10)
# Out:
#                Sales  Discount     Profit
# Quantity
# 1          59.234632  0.152959   8.276396
# 2         120.354488  0.154858  16.006831
# 3         175.201578  0.153329  23.667715
# 4         271.764059  0.157708  37.131310
# 5         337.936339  0.157146  40.257394
# 6         362.101960  0.166556  18.051517
# 7         395.888393  0.161980  56.579163
# 8         458.210802  0.171595  42.244342
# 9         498.083683  0.147946  68.557716
# 10        422.046737  0.190702  35.862404

# %% [markdown]
# #1. sales 2. Discount 3. Profit

# %%
df_quantity.plot.pie(subplots=True, 
                    autopct='%1.1f%%',
                    figsize=(20, 20),
                     pctdistance=0.69,
                    startangle=90,     # start angle 90° (Africa)
                    shadow=True,
                    labels = df_quantity.index)
plt.title('Quantity wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'Quantity wise analysis of Sale, Discount, profit')

# %% [markdown]
# ##### 13 Number of Quantity is high for sales and Profit.

# %% [markdown]
# ### CATAGORY WISE SALES DISCOUNT AND PROFIT

# %%
df_category = df.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()
df_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
df_category.plot.pie(subplots=True, 
                     figsize=(18, 20), 
                     autopct='%1.1f%%', 
                     labels = df_category.index)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f37aa3a4950>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f37a9b10c90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f37a9ac80d0>],
#       dtype=object)

# %% [markdown]
# ##### 1. Maximun sales and Profit obtain in Technology.
# ##### 2. Minimun profit obtain in Furniture

# %% [markdown]
# ### Sub-Category wise Sales, Profit and Discount

# %%
df_sub_category = df.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
df_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918

# %% [markdown]
# # [1] BASED ON THE SALES

# %%
plt.figure(figsize = (15,15))
plt.pie(df_sub_category['Sales'], labels = df_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Sales Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### Copier having highest sales and after that Machine have High sales.

# %% [markdown]
# # [2] BASED ON THE DISCOUNT

# %%
plt.figure(figsize = (15,15))
plt.pie(df_sub_category['Discount'], labels = df_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Discount Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ####*italicized text* Binders, Machines and then tables have high Discount.

# %% [markdown]
# # [3] BASED ON THE PROFIT

# %%
df_sub_category.sort_values('Profit')[['Sales','Profit']].plot(kind='bar',
                                                              figsize= (10,5),
                                                              label=['Avg Sales Price($)','Profit($)'])

# %% [markdown]
# #### COPIER : HIGHEST PROFIT AS WELL AS SELL

# %% [markdown]
# # REGION WISE ANALYSIS

# %%
df_region = df.groupby(['Region'])[['Sales', 'Discount', 'Profit']].mean()
df_region
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.772661  0.240353  17.092709
# East     238.336110  0.145365  32.135808
# South    241.803645  0.147253  28.857673
# West     226.493233  0.109335  33.849032

# %%
df_region.plot.pie(subplots=True, 
                   figsize=(18, 20), 
                   autopct='%1.1f%%',
                   labels = df_region.index)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f37a96f26d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f37a97139d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f37a96c8bd0>],
#       dtype=object)

# %% [markdown]
# ##### WEST : PROFIT IS HIGH

# %% [markdown]
# # SHIP MODE WISE ANALYSIS

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df_shipmode = df.groupby(['Ship Mode'])[['Sales', 'Discount', 'Profit']].mean()

# %%
df_shipmode.plot.pie(subplots=True,
                     figsize=(18, 20), 
                     autopct='%1.1f%%', 
                     labels = df_shipmode.index)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f37a95a8350>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f37a95c8a50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f37a957de50>],
#       dtype=object)

# %% [markdown]
# # RESULT AND CONCLUSION
#
# ### Profit is more than that of sale but there are some areas where profit could be increased.
#
# ### Profit and Discount is high in First Class
#
# ### Sales is high for Same day ship
#
# ### Sub-category: Copier: High Profit & sales
#
# Sub-category: Binders , Machines and then tables have high Discount.
#
# Category: Maximun sales and Profit obtain in Technology.
#
# Category: Minimun profit obtain in Furniture
#
# State: Vermont: Highest Profit
#
# State: Ohio: Lowest Profit
#
# Segment: Home-office: High Profit & sales
#
# Here is top 3 city where deals are Highest.
#
# New York City
#
# Los Angeles
#
# Philadelphia
#
# Sales and Profit are Moderately Correlated.
#
# Quantity and Profit are less Moderately Correlated.
#
# Discount and Profit are Negatively Correlated
#
# Here is top 3 state where deals are Highest.
#
# Califonia
#
# New York
#
# Texas
#
# Wyoming : Lowest Number of deal,Highest amount of sales= Wyoming(11.8%)
#
# Lowest amount of sales= South Dakota(0.8%)
